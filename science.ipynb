# %%
import numpy as np
import matplotlib.pyplot as plt

starttime = 3100
animation_time = 500
times = np.arange(starttime, starttime + animation_time)
p = np.sin(((times - starttime) / animation_time * np.pi))

plt.plot(p)
